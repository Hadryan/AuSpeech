# %%
import numpy as np
import pandas as pd
import gensim
import string
import json
import random

from sklearn.model_selection import train_test_split
from keras.callbacks import LambdaCallback
from keras.layers.recurrent import LSTM
from keras.layers.embeddings import Embedding
from keras.layers import Dense, Activation
from keras.models import Sequential

# %% [markdown]
# ### Load Data

# %%
### Parse CSV File of sentences
utterances = pd.read_csv("../../friends/results.csv")

# %%
### Create Dialog IDs
latest_utterances = {}
def getDialogId(did):
    uid = latest_utterances.get(did, 0)
    latest_utterances[did] = uid + 1
    return "dia{}_utt{}".format(did, uid)

# %%
utterances["Utterance_ID"] = utterances["Dialogue_ID"].apply(getDialogId)

# %%
utterances.head()
# Out:
#                                            Utterance  \
# 0  also i was the point person on my companys tra...
# 1                    you mustve had your hands full.
# 2                            that i did. that i did.
# 3       so lets talk a little bit about your duties.
# 4                             my duties?  all right.
#
#                                                Reply  Season  Episode  \
# 0                    you mustve had your hands full.       8       21
# 1                            that i did. that i did.       8       21
# 2       so lets talk a little bit about your duties.       8       21
# 3                             my duties?  all right.       8       21
# 4  now youll be heading a whole division, so youl...       8       21
#
#    Dialogue_ID                                    Generated_Reply  \
# 0            0  also i was the point person on my companys tra...
# 1            0            that was my bike. it had a missing leg.
# 2            0                  is that what you think?! well, y'
# 3            0                      let me see the door key. hey!
# 4            0  my duties? all right... very good. oh, but loo...
#
#            bleu Utterance_ID
# 0  6.168006e-01    dia0_utt0
# 1  7.290771e-78    dia0_utt1
# 2  6.313993e-78    dia0_utt2
# 3  5.081327e-01    dia0_utt3
# 4  5.775354e-78    dia0_utt4

# %%
audio_embeddings = pd.read_csv("audio_embeddings.csv", index_col=0).sort_index()

# %%
audio_embeddings.head()
# Out:
#                    0         1         2         3         4         5  \
# dia0_utt0   0.468404  0.278676 -0.466101 -0.841499  0.811462  0.994261
# dia0_utt1   0.393439 -0.049780  0.540950  0.341101 -1.450056 -0.316093
# dia0_utt10  0.364907  0.629486  0.278706 -0.984126  0.193778  1.058093
# dia0_utt11  0.320398  0.266720 -0.333487 -0.584721  0.715918  0.393879
# dia0_utt12 -0.063901 -0.062718 -0.055214 -0.043416 -1.132506 -0.409087
#
#                    6         7         8         9        10        11  \
# dia0_utt0   0.079472  0.331361  0.709990 -0.652272  0.534986 -0.043683
# dia0_utt1   0.223109 -0.665428 -0.001696 -0.214290 -0.177799  2.145403
# dia0_utt10  0.347793 -0.489006  1.241197 -0.929034  0.689872  0.935992
# dia0_utt11 -0.152199  0.579379  0.354464 -0.509131  0.413786 -0.606330
# dia0_utt12  0.424417 -0.287484  0.831095  0.186804 -0.437253  1.507920
#
#                   12        13        14        15        16        17  \
# dia0_utt0   0.237591 -0.517976 -0.125858 -0.664146 -0.092333  0.472566
# dia0_utt1  -1.066256  1.891518  0.460961 -2.707002  1.432687  1.104046
# dia0_utt10  0.025185 -0.083003  0.703121 -0.704908 -0.480345  0.544629
# dia0_utt11 -0.009577 -0.631173 -0.258914  0.079926 -0.292592  0.496993
# dia0_utt12 -0.452466  0.811226 -0.392926 -1.476732  0.504981  0.480592
#
#                   18        19
# dia0_utt0  -0.217704 -1.215915
# dia0_utt1  -0.708277  0.283212
# dia0_utt10  0.103707 -1.372710
# dia0_utt11 -0.277546 -0.737783
# dia0_utt12 -0.888524  0.775039

# %% [markdown]
# ### Train Word Embeddings

# %%
docs = list(utterances["Utterance"])
docs.extend(list(utterances["Reply"]))

# %%
max_sentence_len = 40
tokenized_sentences = [[word for word in doc.lower().translate(str.maketrans('','',string.punctuation)).split()[
    :max_sentence_len]] for doc in docs]

# %%
# Train Word2Vec

word_model = gensim.models.Word2Vec(tokenized_sentences, size=50, min_count=0, window=5, iter=100)
pretrained_weights = word_model.wv.vectors
vocab_size, embedding_size = pretrained_weights.shape

# %%
print("Vocab Size:", vocab_size, ", Embedding Size: ", embedding_size)
# Out:
# Vocab Size: 5907 , Embedding Size:  50

# %%
word_model.wv['ambulance']
# Out:
# array([ 0.07773598, -0.29375657, -0.22691308,  0.32868487, -0.18725865,
#         0.09280089, -0.22820775,  0.16686167, -0.00537472,  0.18685572,
#        -0.33349225, -0.05626639, -0.06709337, -0.28205168,  0.07664964,
#        -0.17803718,  0.32260135, -0.05070792,  0.19358161,  0.18862797,
#        -0.05803084, -0.31198484, -0.05836983, -0.23335382, -0.12515719,
#        -0.46920678,  0.3272013 , -0.03200192,  0.1112607 , -0.12537071,
#         0.07637703, -0.16718976,  0.2437104 , -0.27371076, -0.1978086 ,
#         0.08723114,  0.0630024 , -0.6420263 , -0.00084112,  0.12879665,
#        -0.00786434,  0.2639555 ,  0.29323307,  0.13385877, -0.14369838,
#        -0.23961295, -0.11977836, -0.62264687,  0.02373069,  0.44756612],
#       dtype=float32)

# %%
word_model.save("meld_text_w2v.model")

# %%
# Checking that model is properly trained
for word in ['model', 'joey', 'learn']:
  most_similar = ', '.join('%s (%.2f)' % (similar, dist) for similar, dist in word_model.wv.most_similar(word)[:8])
  print('  %s -> %s' % (word, most_similar))
# Out:
#   model -> victorias (0.94), boxer (0.78), kristindoes (0.76), girlie (0.74), shorts (0.73), fundamentally (0.69), stephanie (0.69), unmarriable (0.67)
#   joey -> chandler (0.52), sure (0.50), rachel (0.49), ross (0.45), you (0.45), cause (0.43), i (0.43), way (0.42)
#   learn -> react (0.55), bambi (0.50), maroon (0.49), handshake (0.47), waitwait (0.47), youhow (0.46), thathot (0.45), split (0.44)

# %%
def word2idx(word):
  return word_model.wv.vocab[word].index

def idx2word(idx):
  return word_model.wv.index2word[idx]

# %%
word2idx("joey")
# Out:
# 80

# %%
idx2word(80)
# Out:
# 'joey'

# %% [markdown]
# ### Combine Word and Audio Embeddings

# %%
filtered_utterances = utterances[utterances["Utterance_ID"].isin(list(audio_embeddings.index))].copy()

# %%
filtered_utterances.shape
# Out:
# (7985, 8)

# %%
utterance_key2idx = {}
utterance_idx2key = {}
utterance_key2idx_words = {}

combined_weights = []
filtered_sentences = []
final_idx = 0

def combineWeights(row):
    global final_idx
    
    complete_sentence = row["Utterance"] + " " + row["Reply"]
    utt = [word for word in complete_sentence.lower().translate(
        str.maketrans('','',string.punctuation)).split()[:max_sentence_len]]
    uid = row["Utterance_ID"]
    filtered_sentences.append(utt)
    audio_vector = np.array(audio_embeddings.loc[uid])
    for word in utt:
        word_vector = pretrained_weights[word2idx(word)]
        if uid not in utterance_key2idx:
            utterance_key2idx[uid] = {}
        
        if word not in utterance_key2idx_words:
            utterance_key2idx_words[word] = {}
            
        utterance_key2idx[uid][word] = final_idx
        utterance_idx2key[final_idx] = (uid, word)
        
        utterance_key2idx_words[word][uid] = final_idx
        
        combined_weights.append(np.append(audio_vector, word_vector))
        
        final_idx += 1
    
    return " ".join(utt)
        
filtered_utterances["tokens"] = filtered_utterances.apply(combineWeights, axis=1)
combined_weights = np.array(combined_weights)

# %%
combined_weights.shape
# Out:
# (125768, 70)

# %%
np.save("combined_weights", combined_weights)

# %%
with open("combined_weights_key2idx.json", "w") as fp:
    json.dump(utterance_key2idx, fp)

# %%
with open("combined_weights_idx2key.json", "w") as fp:
    json.dump(utterance_idx2key, fp)

# %%
with open("combined_weights_key2idx_words.json", "w") as fp:
    json.dump(utterance_key2idx_words, fp)

# %%
filtered_utterances.to_csv("filtered_utterances_tokens.csv", index=False)

# %% [markdown]
# ### Create Training and Testing Data

# %%
train, test = train_test_split(filtered_utterances, test_size = 0.01)

# %%
train.to_csv("lstm_train.csv", index=False)
test.to_csv("lstm_test.csv", index=False)

# %%
train_sentences = list(train["tokens"])
train_ids = list(train["Utterance_ID"])

test_sentences = list(test["tokens"])
test_ids = list(test["Utterance_ID"])

# %%
train_x = np.zeros([len(train_sentences), max_sentence_len], dtype=np.int32)
train_y = np.zeros([len(train_sentences)], dtype=np.int32)

for i, sentence_str in enumerate(train_sentences):
    sentence = sentence_str.split()
    sid = train_ids[i]
    for t, word in enumerate(sentence[:-1]):
        train_x[i, t] = utterance_key2idx[sid][word]
    train_y[i] = utterance_key2idx[sid][sentence[-1]]
    
print('train_x shape:', train_x.shape)
print('train_y shape:', train_y.shape)
# Out:
# train_x shape: (7905, 40)
# train_y shape: (7905,)

# %%
test_x = np.zeros([len(test_sentences), max_sentence_len], dtype=np.int32)
test_y = np.zeros([len(test_sentences)], dtype=np.int32)

for i, sentence_str in enumerate(test_sentences):
    sentence = sentence_str.split()
    sid = test_ids[i]
    for t, word in enumerate(sentence[:-1]):
        test_x[i, t] = utterance_key2idx[sid][word]
    test_y[i] = utterance_key2idx[sid][sentence[-1]]
    
print('test_x shape:', test_x.shape)
print('test_y shape:', test_y.shape)
# Out:
# test_x shape: (80, 40)
# test_y shape: (80,)

# %% [markdown]
# ### Create Model

# %%
combined_embedding_size = combined_weights.shape[1]

# %%
model = Sequential()
model.add(Embedding(input_dim=combined_weights.shape[0], output_dim=combined_weights.shape[1], weights=[combined_weights]))
model.add(LSTM(units=combined_embedding_size))
model.add(Dense(units=combined_weights.shape[0]))
model.add(Activation('softmax'))
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy')

# %%
def sample(preds, temperature=1.0):
    if temperature <= 0:
        return np.argmax(preds)
    
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    
    return np.argmax(probas)

def generate_next(text, num_generated=10):
    word_idxs = [random.choice(list(utterance_key2idx_words[word].values())) for word in text.lower().split()]
    for i in range(num_generated):
        prediction = model.predict(x=np.array(word_idxs))
        idx = sample(prediction[-1], temperature=0.7)
        word_idxs.append(idx)
    return ' '.join(utterance_idx2key[idx][1] for idx in word_idxs)

def on_epoch_end(epoch, _):
    print('\nGenerating text after epoch: %d' % epoch)
    texts = [
        'you mustve had your hands full',
        'oh wait i',
        'oh wait i',
        'sorry about that',
    ]
    for text in texts:
        sample = generate_next(text)
        print('%s... -> %s' % (text, sample))

# %%
model.fit(train_x, train_y,
        batch_size=128,
        epochs=100,
        callbacks=[LambdaCallback(on_epoch_end=on_epoch_end)])
# Out:
# Epoch 1/100
# 7905/7905 [==============================] - 16s 2ms/step - loss: 2.2333
#
# Generating text after epoch: 0
# you mustve had your hands full... -> you mustve had your hands full ya geller kay i eight think scared was games no
# oh wait i... -> oh wait i annabelle half so in okay really ya 830 yknow done
# oh wait i... -> oh wait i night fine right so it interesting wanted its to joke
# sorry about that... -> sorry about that yours pillow if be ohh a out it girl monana
# Epoch 2/100
# 7905/7905 [==============================] - 16s 2ms/step - loss: 2.9881
#
# Generating text after epoch: 1
# you mustve had your hands full... -> you mustve had your hands full great naked because lot me why convention he pay chef
# oh wait i... -> oh wait i cute why do girl cant urgent oop now out remembered
# oh wait i... -> oh wait i mean thing rach doing are said again why year comes
# sorry about that... -> sorry about that kid joey 830 in we night thinking poem he sissy
# Epoch 3/100
# 7905/7905 [==============================] - 16s 2ms/step - loss: 2.5911
#
# Generating text after epoch: 2
# you mustve had your hands full... -> you mustve had your hands full claims a me know could questions action ok kristin things
# oh wait i... -> oh wait i thats careful real sisters hey to fair me phoebe crap
# oh wait i... -> oh wait i maniac see pear advice dont but whispering wewere yuhhuh out
# sorry about that... -> sorry about that do yeah your know this you you sorry were monica
# Epoch 4/100
# 7905/7905 [==============================] - 16s 2ms/step - loss: 2.3418
#
# Generating text after epoch: 3
# you mustve had your hands full... -> you mustve had your hands full spatters at right you you people out and you little
# oh wait i... -> oh wait i movies busy you okay years you to doesnt already to
# oh wait i... -> oh wait i lie this else of really by was hey right life
# sorry about that... -> sorry about that enough strong pages almost its i here know speed that
# Epoch 5/100
# 7905/7905 [==============================] - 16s 2ms/step - loss: 2.3103
#
# Generating text after epoch: 4
# you mustve had your hands full... -> you mustve had your hands full ahh we jaw well down guys too with grabgrab i
# oh wait i... -> oh wait i is didnt dont together sex and tired window gift want
# oh wait i... -> oh wait i cool okay treeger joey hey no we later thinkoh do
# sorry about that... -> sorry about that sissy would gonna and happening were you sick lady what
# Epoch 6/100
# 7905/7905 [==============================] - 16s 2ms/step - loss: 2.2282
#
# Generating text after epoch: 5
# you mustve had your hands full... -> you mustve had your hands full sure story honor morning much it it god taboo its
# oh wait i... -> oh wait i her to one yknow hand the could im spatters it
# oh wait i... -> oh wait i paths they again jew we wine out boy chandler asked
# sorry about that... -> sorry about that what doing something this when designers my umm no fell
# Epoch 7/100
# 7905/7905 [==============================] - 16s 2ms/step - loss: 2.1966
#
# Generating text after epoch: 6
# you mustve had your hands full... -> you mustve had your hands full christmas i needle celtics not what yeah go returning boom
# oh wait i... -> oh wait i isis right i goes i okay absolutely hi sweater fun
# oh wait i... -> oh wait i upset people taking out him nono that babies happens yknow
# sorry about that... -> sorry about that knives you here 23 oh whoa yeah on its it
# Epoch 8/100
# 7905/7905 [==============================] - 16s 2ms/step - loss: 2.1712
#
# Generating text after epoch: 7
# you mustve had your hands full... -> you mustve had your hands full not me go yeah not about the here island won
# oh wait i... -> oh wait i howd in yeah are that blast about here on whatwhat
# oh wait i... -> oh wait i and car well done yuhhuh yeah it yeah alone gonna
# sorry about that... -> sorry about that right laminated tonight thanks i to are up it comes
# Epoch 9/100
# 7905/7905 [==============================] - 16s 2ms/step - loss: 2.1410
#
# Generating text after epoch: 8
# you mustve had your hands full... -> you mustve had your hands full pack it just eleven what you that so to whatwhat
# oh wait i... -> oh wait i there nothin disgustingtons saying ok around no hi out fine
# oh wait i... -> oh wait i what is there money phone gonna yknow i play dirty
# sorry about that... -> sorry about that know one 800 name on bing the not so out
# Epoch 10/100
# 7905/7905 [==============================] - 16s 2ms/step - loss: 2.1235
#
# Generating text after epoch: 9
# you mustve had your hands full... -> you mustve had your hands full wesley you god right terrible it do so i and
# oh wait i... -> oh wait i for they problem clear courthouse okay exactly okay market and
# oh wait i... -> oh wait i when oh you out no too other suggestions something apartment
# sorry about that... -> sorry about that alan joey em and too manage that this sorry married
# Epoch 11/100
# 7905/7905 [==============================] - 16s 2ms/step - loss: 2.1000
#
# Generating text after epoch: 10
# you mustve had your hands full... -> you mustve had your hands full cup this yeah you pretty why do coffee at it
# oh wait i... -> oh wait i well joey place are dammit joey wow touch oh then
# oh wait i... -> oh wait i area it okay now why lie kidding rach that us
# sorry about that... -> sorry about that what cleveland here now we better going are later now
# Epoch 12/100
# 7905/7905 [==============================] - 16s 2ms/step - loss: 2.0864
#
# Generating text after epoch: 11
# you mustve had your hands full... -> you mustve had your hands full yeah call yeah scary right is know right thought think
# oh wait i... -> oh wait i stop stop again think this but back umm oh widower
# oh wait i... -> oh wait i wet hole do 400 get with fyi dknow there left
# sorry about that... -> sorry about that under go weird get this sorry fire celtics sandwich babies
# Epoch 13/100
# 7905/7905 [==============================] - 16s 2ms/step - loss: 2.0828
#
# Generating text after epoch: 12
# you mustve had your hands full... -> you mustve had your hands full hey minister feel job roger oh turn roommate right is
# oh wait i... -> oh wait i that different so hey remember foxtrot woman zero im ones
# oh wait i... -> oh wait i how again i later uhhuh idea pig two met help
# sorry about that... -> sorry about that of i i lounge god the get coin great deal
# Epoch 14/100
# 7905/7905 [==============================] - 16s 2ms/step - loss: 2.0642
#
# Generating text after epoch: 13
# you mustve had your hands full... -> you mustve had your hands full it was movie wedding no okay exciting jealous didnt okay
# oh wait i... -> oh wait i one roots human that it winross what all go is
# oh wait i... -> oh wait i kid hi howd me watch tramp system why this we
# sorry about that... -> sorry about that could yknow souvenirs both i bake ok skidmark the i
# Epoch 15/100
# 7905/7905 [==============================] - 16s 2ms/step - loss: 2.0628
#
# Generating text after epoch: 14
# you mustve had your hands full... -> you mustve had your hands full wheel place that write many me a oh phoebe highness
# oh wait i... -> oh wait i took a with hi i now do was name greg
# oh wait i... -> oh wait i hours and be together oh thats her exactly what were
# sorry about that... -> sorry about that you imagine sorry you wrong pear smock the soup would
# Epoch 16/100
# 7905/7905 [==============================] - 16s 2ms/step - loss: 2.0402
#
# Generating text after epoch: 15
# you mustve had your hands full... -> you mustve had your hands full wondering sweater im ohoh hey no its ahh like pheebs
# oh wait i... -> oh wait i to this wait ugh yeah else to that go job
# oh wait i... -> oh wait i nine let okay note ever in really phd you feels
# sorry about that... -> sorry about that huh in ah really going days thing girlfriend kid minute
# Epoch 17/100
# 7905/7905 [==============================] - 16s 2ms/step - loss: 2.0175
#
# Generating text after epoch: 16
# you mustve had your hands full... -> you mustve had your hands full no right a okay a rude alright get monica player
# oh wait i... -> oh wait i movie right okay maurice guys yesterday on hazel wedgie bed
# oh wait i... -> oh wait i while i out one disagree sure my though rach down
# sorry about that... -> sorry about that no its matter call mess what on first donuts did
# Epoch 18/100
# 7905/7905 [==============================] - 16s 2ms/step - loss: 1.9992
#
# Generating text after epoch: 17
# you mustve had your hands full... -> you mustve had your hands full matter i want who one brutal wonderful that enough david
# oh wait i... -> oh wait i and sucker freak here somethin hey i well kids frank
# oh wait i... -> oh wait i actually listen again it museum that ball not ahh before
# sorry about that... -> sorry about that long ready view so ow awful picked wanna him gina
# Epoch 19/100
# 7905/7905 [==============================] - 16s 2ms/step - loss: 1.9837
#
# Generating text after epoch: 18
# you mustve had your hands full... -> you mustve had your hands full wesley uhhuh monica plans ill syracuse here woman god he
# oh wait i... -> oh wait i have oh here okay about if again is it barcelona
# oh wait i... -> oh wait i mean off me find thats him rachel fine you i
# sorry about that... -> sorry about that it on whoohoho damage im this up this ive hey
# Epoch 20/100
# 7905/7905 [==============================] - 16s 2ms/step - loss: 1.9575
#
# Generating text after epoch: 19
# you mustve had your hands full... -> you mustve had your hands full issues this god ah ask so sucks some is music
# oh wait i... -> oh wait i you gate didnt massage scrud uh hi out you rules
# oh wait i... -> oh wait i dont to me was tulsa important what wait thoughts have
# sorry about that... -> sorry about that close in sucker owow then break here betcha love there
# Epoch 21/100
# 7905/7905 [==============================] - 16s 2ms/step - loss: 1.9504
#
# Generating text after epoch: 20
# you mustve had your hands full... -> you mustve had your hands full really have i what time haha please i all it
# oh wait i... -> oh wait i dont basis leaving did shhh we okay right to find
# oh wait i... -> oh wait i daddy hey a does earrings he that feel i bing
# sorry about that... -> sorry about that thing tomatoes gay seconds and the like yeah kids on
# Epoch 22/100
# 7905/7905 [==============================] - 16s 2ms/step - loss: 2.1738
#
# Generating text after epoch: 21
# you mustve had your hands full... -> you mustve had your hands full yeah i warning okay what bumps to true help work
# oh wait i... -> oh wait i ok okay there that bugs away human her this now
# oh wait i... -> oh wait i show him yeah restaurantits ross maybe chandler it here have
# sorry about that... -> sorry about that it now sorry wells it do idea no yknow is
# Epoch 23/100
# 7905/7905 [==============================] - 17s 2ms/step - loss: 2.0485
#
# Generating text after epoch: 22
# you mustve had your hands full... -> you mustve had your hands full okay right i then you great you other your like
# oh wait i... -> oh wait i but calling the lot rather and up us sir you
# oh wait i... -> oh wait i just be again it think tomorrow me scrud thank shelley
# sorry about that... -> sorry about that whatever boat okay does that that yeah means doesnt yeah
# Epoch 24/100
# 7905/7905 [==============================] - 17s 2ms/step - loss: 1.9875
#
# Generating text after epoch: 23
# you mustve had your hands full... -> you mustve had your hands full cornered little coat yep sweet dont but wedding hardest time
# oh wait i... -> oh wait i yeah cruel either oh one 2000 me draft when promise
# oh wait i... -> oh wait i chipper next it the the theyre god hi place so
# sorry about that... -> sorry about that monica wow place alan the 8 a i fine me
# Epoch 25/100
# 7905/7905 [==============================] - 16s 2ms/step - loss: 1.9268
#
# Generating text after epoch: 24
# you mustve had your hands full... -> you mustve had your hands full awwwww her tomatoes really back mad no some so weeks
# oh wait i... -> oh wait i them thats sandwiches her exactly you stick it speed tada
# oh wait i... -> oh wait i it god the there something of that no yknow you
# sorry about that... -> sorry about that i doing me happen yknow you noo brave shmair you
# Epoch 26/100
# 7905/7905 [==============================] - 16s 2ms/step - loss: 1.8936
#
# Generating text after epoch: 25
# you mustve had your hands full... -> you mustve had your hands full who just no big you oooooooooooooohhhhhhhhhhh it ever neither youre
# oh wait i... -> oh wait i market present you go mean scott will player fun underwear
# oh wait i... -> oh wait i it you kick it me really a socket party sweet
# sorry about that... -> sorry about that nothing big tie mississpete though be teddy it face well
# Epoch 27/100
# 7905/7905 [==============================] - 16s 2ms/step - loss: 1.8774
#
# Generating text after epoch: 26
# you mustve had your hands full... -> you mustve had your hands full two nooo no paid ross ii this these come yet
# oh wait i... -> oh wait i to whoawhoawhoa it to mean me see joey me him
# oh wait i... -> oh wait i on me you pheebs sorry i ever no give calcutta
# sorry about that... -> sorry about that what doin why great stuff awful up ross modeling guy
# Epoch 28/100
# 7905/7905 [==============================] - 16s 2ms/step - loss: 1.8475
#
# Generating text after epoch: 27
# you mustve had your hands full... -> you mustve had your hands full funny morning huh nothing is wouldve my why be pirate
# oh wait i... -> oh wait i think right pi yet what what guys be time matter
# oh wait i... -> oh wait i waitwaitwaitwaitwaitwaitwaitwait round the do a talking okay honor oh together
# sorry about that... -> sorry about that of nervous and penis the room guys leave tango english
# Epoch 29/100
# 7905/7905 [==============================] - 16s 2ms/step - loss: 1.8294
#
# Generating text after epoch: 28
# you mustve had your hands full... -> you mustve had your hands full a nothing thing you right to clothes kidding went that
# oh wait i... -> oh wait i one thing right get bye home that no right here
# oh wait i... -> oh wait i him pretty going youre hi first this man true top
# sorry about that... -> sorry about that whatever amazing could left pheebs mom as come joey exactly
# Epoch 30/100
# 7905/7905 [==============================] - 16s 2ms/step - loss: 1.8405
#
# Generating text after epoch: 29
# you mustve had your hands full... -> you mustve had your hands full mine me why it i go la boobies game call
# oh wait i... -> oh wait i casey all hand now nuts sex here idea joey pheebs
# oh wait i... -> oh wait i monroe that yes because what go night say robert crap
# sorry about that... -> sorry about that think i session here guy stick doing on that you
# Epoch 31/100
# 7905/7905 [==============================] - 17s 2ms/step - loss: 1.8428
#
# Generating text after epoch: 30
# you mustve had your hands full... -> you mustve had your hands full like phoebe all no possible wesley able what name first
# oh wait i... -> oh wait i killed those message oh chandler suicide good okay him sweet
# oh wait i... -> oh wait i been 48 for what to lie hey often uhhuh dismissed
# sorry about that... -> sorry about that ahh i well jealous talking it so what idea problem
# Epoch 32/100
# 7905/7905 [==============================] - 17s 2ms/step - loss: 1.8186
#
# Generating text after epoch: 31
# you mustve had your hands full... -> you mustve had your hands full claims at letters one hey leave enough party breaths goofing
# oh wait i... -> oh wait i what you that before board yes out what printed gotta
# oh wait i... -> oh wait i shot excuse you no crazy see thank anymore it hi
# sorry about that... -> sorry about that thinking oh then now 2000 a butcome enjoying im then
# Epoch 33/100
# 7905/7905 [==============================] - 16s 2ms/step - loss: 1.8256
#
# Generating text after epoch: 32
# you mustve had your hands full... -> you mustve had your hands full moving good night seen ramorays was thumb squash talking underwear
# oh wait i... -> oh wait i there bens rogers shot the lie were why your jenny
# oh wait i... -> oh wait i at luck about you either about rach carol one hurt
# sorry about that... -> sorry about that you off rachel joke go that heyhey it im true
# Epoch 34/100
# 7905/7905 [==============================] - 16s 2ms/step - loss: 1.7769
#
# Generating text after epoch: 33
# you mustve had your hands full... -> you mustve had your hands full kissed hello your pants does you fortune know brutal im
# oh wait i... -> oh wait i borrowed things the but get room really i i you
# oh wait i... -> oh wait i want what stop what serious them a cute name to
# sorry about that... -> sorry about that phoebe embarrassed thats cmere are tonight coats of took want
# Epoch 35/100
# 7905/7905 [==============================] - 16s 2ms/step - loss: 1.7439
#
# Generating text after epoch: 34
# you mustve had your hands full... -> you mustve had your hands full so think adoin here yeah not stores candy then you
# oh wait i... -> oh wait i right and she was 23 isnt stick them jill if
# oh wait i... -> oh wait i cares went great is cheap know wait really paper her
# sorry about that... -> sorry about that dont been hip wanna justif doesnt it uhhmm okay photographer
# Epoch 36/100
# 7905/7905 [==============================] - 16s 2ms/step - loss: 1.7337
#
# Generating text after epoch: 35
# you mustve had your hands full... -> you mustve had your hands full dime down lesbian fights no baby that her here why
# oh wait i... -> oh wait i on yeah wedding jake is how kinda tell it haha
# oh wait i... -> oh wait i for pheebs it gonna why mail it to out out
# sorry about that... -> sorry about that hard andand in pheebs anything you yet it where you
# Epoch 37/100
# 7905/7905 [==============================] - 16s 2ms/step - loss: 1.7184
#
# Generating text after epoch: 36
# you mustve had your hands full... -> you mustve had your hands full so there what bamboozled i me yes really funny black
# oh wait i... -> oh wait i here no ever sir what promise books you rachel up
# oh wait i... -> oh wait i goodpill was see sorry us to oh dammit something question
# sorry about that... -> sorry about that of i what on place huh kip again her relax
# Epoch 38/100
# 7905/7905 [==============================] - 16s 2ms/step - loss: 1.7147
#
# Generating text after epoch: 37
# you mustve had your hands full... -> you mustve had your hands full stealing yeah uhh it mine fine lost waitressing time hmmm
# oh wait i... -> oh wait i really name fear yeah that hates calling excuse control but
# oh wait i... -> oh wait i idiot huh joe open we dont do ross over unless
# sorry about that... -> sorry about that and hey pickle looked ive thats now over thing not
# Epoch 39/100
# 7905/7905 [==============================] - 16s 2ms/step - loss: 1.7209
#
# Generating text after epoch: 38
# you mustve had your hands full... -> you mustve had your hands full done to from layer okay been that sweater yay balded
# oh wait i... -> oh wait i mail yknow mississpete phone yours dinner bra comet you good
# oh wait i... -> oh wait i what what ugly talk ridiculous of lady marcel god thurman
# sorry about that... -> sorry about that so go was you wrong have want me you is
# Epoch 40/100
# 7905/7905 [==============================] - 16s 2ms/step - loss: 1.6834
#
# Generating text after epoch: 39
# you mustve had your hands full... -> you mustve had your hands full conscious knew it what that and pregnant rosss you set
# oh wait i... -> oh wait i did dollars something brave youll down judgmental right kinda mrs
# oh wait i... -> oh wait i i paths hear joey gift whos martin done today rachel
# sorry about that... -> sorry about that cant that can ball me together sweet cant uhh enough
# Epoch 41/100
# 7905/7905 [==============================] - 16s 2ms/step - loss: 1.6853
#
# Generating text after epoch: 40
# you mustve had your hands full... -> you mustve had your hands full true machine card man on hi me there down crap
# oh wait i... -> oh wait i huh out yeah rosss yes order to stairway em eat
# oh wait i... -> oh wait i popular you lets okay home going ii the joey here
# sorry about that... -> sorry about that right sake never account inappropriate thanks here happen anymore my
# Epoch 42/100
# 7905/7905 [==============================] - 16s 2ms/step - loss: 1.6608
#
# Generating text after epoch: 41
# you mustve had your hands full... -> you mustve had your hands full name sorry and purse this ben him please and every
# oh wait i... -> oh wait i really date coffee heart you can really mean well man
# oh wait i... -> oh wait i wonderful is how one cowboy that hooked that candy morning
# sorry about that... -> sorry about that chandler it this her what hi came do please her
# Epoch 43/100
# 7905/7905 [==============================] - 17s 2ms/step - loss: 1.7291
#
# Generating text after epoch: 42
# you mustve had your hands full... -> you mustve had your hands full ago bastard yeah all second are room feel paid what
# oh wait i... -> oh wait i go sweet you problem yeah who okay sorry movie quarter
# oh wait i... -> oh wait i well does thing chandler night lot to thewowww rachel on
# sorry about that... -> sorry about that scary right up oh relationship person a knapsack had i
# Epoch 44/100
# 7905/7905 [==============================] - 17s 2ms/step - loss: 1.7666
#
# Generating text after epoch: 43
# you mustve had your hands full... -> you mustve had your hands full a hey thank oh rach relax there im ahh mom
# oh wait i... -> oh wait i mine yep kid me no telling with one team said
# oh wait i... -> oh wait i still ya again me was on expression go here bones
# sorry about that... -> sorry about that chelsea weird they right ow hole band review uhhmm inspector
# Epoch 45/100
# 7905/7905 [==============================] - 16s 2ms/step - loss: 1.7424
#
# Generating text after epoch: 44
# you mustve had your hands full... -> you mustve had your hands full chandler hand knows are so he uhh duck much perform
# oh wait i... -> oh wait i one me was do freak joey well this mind and
# oh wait i... -> oh wait i these lets do on right have go been girl job
# sorry about that... -> sorry about that one huntley you detail maybe at a me doin again
# Epoch 46/100
# 7905/7905 [==============================] - 16s 2ms/step - loss: 1.6527
#
# Generating text after epoch: 45
# you mustve had your hands full... -> you mustve had your hands full a remembered else good going you so organic sold review
# oh wait i... -> oh wait i you what are what gift gonna your me okay yeah
# oh wait i... -> oh wait i pants whoa you london this what funny rach move rach
# sorry about that... -> sorry about that mine go lemonade privacy hey believe there teddy off muscles
# Epoch 47/100
# 7905/7905 [==============================] - 16s 2ms/step - loss: 1.5931
#
# Generating text after epoch: 46
# you mustve had your hands full... -> you mustve had your hands full what shh question asleep night uhhuh you dont day stevens
# oh wait i... -> oh wait i friends what are pack sorry am it suzie sorry else
# oh wait i... -> oh wait i this gay kind woman lotion phoebe pl pretty hey so
# sorry about that... -> sorry about that have honey sir them guy work damnit men morning this
# Epoch 48/100
# 7905/7905 [==============================] - 16s 2ms/step - loss: 1.5453
#
# Generating text after epoch: 47
# you mustve had your hands full... -> you mustve had your hands full true just friends mom yet cool it up at the
# oh wait i... -> oh wait i far suggestions this it happy i her lotion dude chandler
# oh wait i... -> oh wait i up nope yeah angel in one yeah scary you a
# sorry about that... -> sorry about that of thanks will watch girlfriend practice time i device monica
# Epoch 49/100
# 7905/7905 [==============================] - 16s 2ms/step - loss: 1.5163
#
# Generating text after epoch: 48
# you mustve had your hands full... -> you mustve had your hands full even phoebe fault joey ross phoebe gonna a the totally
# oh wait i... -> oh wait i other wouldve up thisahhaha up lovers listen down finger party
# oh wait i... -> oh wait i exactly doing best there green time what good alone feels
# sorry about that... -> sorry about that now look for you at mmhm guys hi bucket will
# Epoch 50/100
# 7905/7905 [==============================] - 16s 2ms/step - loss: 1.4930
#
# Generating text after epoch: 49
# you mustve had your hands full... -> you mustve had your hands full dime sorry anyway mmhm watch ok off pushing not coffee
# oh wait i... -> oh wait i on turn really what problem yeah yeah coffee know hour
# oh wait i... -> oh wait i do up phoebe that him you not me stuff uhoh
# sorry about that... -> sorry about that i ross there yeah coffee this yeah it there do
# Epoch 51/100
# 7905/7905 [==============================] - 16s 2ms/step - loss: 1.4832
#
# Generating text after epoch: 50
# you mustve had your hands full... -> you mustve had your hands full monica maybe are out chandler shy how are mean you
# oh wait i... -> oh wait i it long there apartment with rach rachel food yeah yeah
# oh wait i... -> oh wait i carefully umhmm plans okay order bet you want people friend
# sorry about that... -> sorry about that him sweater stevens die yeah doing your together girl wedding
# Epoch 52/100
# 7905/7905 [==============================] - 16s 2ms/step - loss: 1.4691
#
# Generating text after epoch: 51
# you mustve had your hands full... -> you mustve had your hands full what back see rule jokes monica love that uhoh with
# oh wait i... -> oh wait i that yeah son yeah cant oh unbelievable anyway it relax
# oh wait i... -> oh wait i problem box and secret worry thats pack sets thinking everybody
# sorry about that... -> sorry about that one the party hey go yeah us here look cooking
# Epoch 53/100
# 7905/7905 [==============================] - 16s 2ms/step - loss: 1.4565
#
# Generating text after epoch: 52
# you mustve had your hands full... -> you mustve had your hands full huh you tonight no chip about anyway sorry rip stevens
# oh wait i... -> oh wait i mom sorry for you moustache what diego that unbelievable basis
# oh wait i... -> oh wait i we over inspector did again duties say please tell ross
# sorry about that... -> sorry about that way be gonna chandler youyouyou robe word we barcelona something
# Epoch 54/100
# 7905/7905 [==============================] - 16s 2ms/step - loss: 1.4388
#
# Generating text after epoch: 53
# you mustve had your hands full... -> you mustve had your hands full everybody lying most a to guy ezels so am but
# oh wait i... -> oh wait i last is just phone i ever youre word special two
# oh wait i... -> oh wait i hey applied well the joey mine wine will do have
# sorry about that... -> sorry about that you right hi chef it go window most sitting monica
# Epoch 55/100
# 7905/7905 [==============================] - 16s 2ms/step - loss: 1.4255
#
# Generating text after epoch: 54
# you mustve had your hands full... -> you mustve had your hands full yeah one one way friend this me idea right tulsa
# oh wait i... -> oh wait i chandler for monica battery when birds she no okay out
# oh wait i... -> oh wait i why mind big to okay joey much know ones you
# sorry about that... -> sorry about that uh go just im know treeger too um are is
# Epoch 56/100
# 7905/7905 [==============================] - 16s 2ms/step - loss: 1.4140
#
# Generating text after epoch: 55
# you mustve had your hands full... -> you mustve had your hands full a been old women now noooo really down me what
# oh wait i... -> oh wait i but fortune hmmmm you we night who what this little
# oh wait i... -> oh wait i sorry are soon janice doing then jill me was am
# sorry about that... -> sorry about that night say hey you god out sorry is stupid then
# Epoch 57/100
# 7905/7905 [==============================] - 16s 2ms/step - loss: 1.3921
#
# Generating text after epoch: 56
# you mustve had your hands full... -> you mustve had your hands full unbelievable yeah idea donuts okay freak have i huh ready
# oh wait i... -> oh wait i cute that me yeah we him mine control them and
# oh wait i... -> oh wait i say with birth yeah a a father i you a
# sorry about that... -> sorry about that a hi up no what nothing thing great do be
# Epoch 58/100
# 7905/7905 [==============================] - 16s 2ms/step - loss: 1.3712
#
# Generating text after epoch: 57
# you mustve had your hands full... -> you mustve had your hands full right a because joey phoebe date right what what no
# oh wait i... -> oh wait i upset sisters up anything either thing daddy to why yours
# oh wait i... -> oh wait i it that lotion great over it bike everybody party yeah
# sorry about that... -> sorry about that right see sorry god combination combination no cat sorry i
# Epoch 59/100
# 7905/7905 [==============================] - 16s 2ms/step - loss: 1.3553
#
# Generating text after epoch: 58
# you mustve had your hands full... -> you mustve had your hands full breaths joey what okay quarter to you 13 very breathe
# oh wait i... -> oh wait i that was sea smooth hey uhoh no grade no a
# oh wait i... -> oh wait i some you on why interview nooo guess where oh her
# sorry about that... -> sorry about that this on take party was up chatracus on on okay
# Epoch 60/100
# 7905/7905 [==============================] - 16s 2ms/step - loss: 1.4340
#
# Generating text after epoch: 59
# you mustve had your hands full... -> you mustve had your hands full god cry feel gentlemen expression for god hey may fantasy
# oh wait i... -> oh wait i there gina enough pumpkin there tell possible baby underwear ahh
# oh wait i... -> oh wait i his her ohhh yeah you want losing i ok work
# sorry about that... -> sorry about that it mine hand ring off uh you detail sorry penis
# Epoch 61/100
# 7905/7905 [==============================] - 16s 2ms/step - loss: 1.4005
#
# Generating text after epoch: 60
# you mustve had your hands full... -> you mustve had your hands full yeah mugsy that word dog kid you no him goggles
# oh wait i... -> oh wait i no gonna was salami years will spatters it wrong up
# oh wait i... -> oh wait i fancy whoa hey this youre bigger hey smart it hey
# sorry about that... -> sorry about that that sensitive up me why up it this pack me
# Epoch 62/100
# 7905/7905 [==============================] - 16s 2ms/step - loss: 1.3557
#
# Generating text after epoch: 61
# you mustve had your hands full... -> you mustve had your hands full so coffee if stairway eligible to okay syracuse tomatoes her
# oh wait i... -> oh wait i women me roommate the there here so night canoe rain
# oh wait i... -> oh wait i well tango a oh english oh jackass feet because cowboy
# sorry about that... -> sorry about that hey rather hey old overall mind it night listen possible
# Epoch 63/100
# 7905/7905 [==============================] - 16s 2ms/step - loss: 1.3263
#
# Generating text after epoch: 62
# you mustve had your hands full... -> you mustve had your hands full you no no us obviously now to annabelle thats barcelona
# oh wait i... -> oh wait i god thurman problem yeah of okay have monica it yeah
# oh wait i... -> oh wait i nothing mess plan phoebe is second you sorry him you
# sorry about that... -> sorry about that you you fortune know you thinking complaint focus down moodkiller
# Epoch 64/100
# 7905/7905 [==============================] - 16s 2ms/step - loss: 1.3137
#
# Generating text after epoch: 63
# you mustve had your hands full... -> you mustve had your hands full god hi happen joke no it there me you huh
# oh wait i... -> oh wait i you hey and common i ever are know you wanna
# oh wait i... -> oh wait i alan and ew them we house really hundred a have
# sorry about that... -> sorry about that right uhoh im right top going dont safe wine then
# Epoch 65/100
# 7905/7905 [==============================] - 16s 2ms/step - loss: 1.3411
#
# Generating text after epoch: 64
# you mustve had your hands full... -> you mustve had your hands full different yeah handle if down right that yeah crap what
# oh wait i... -> oh wait i you up guys grade sex possible say mess brave six
# oh wait i... -> oh wait i really experience dont here are what yeah yeah actually her
# sorry about that... -> sorry about that school god you game somewhere tanned me gina quarter yours
# Epoch 66/100
# 7905/7905 [==============================] - 16s 2ms/step - loss: 1.3159
#
# Generating text after epoch: 65
# you mustve had your hands full... -> you mustve had your hands full wont no no hall get whoa what are yeah bigger
# oh wait i... -> oh wait i hypothetically dark big joey ross yeah who like i year
# oh wait i... -> oh wait i me place colon we some out money week know bing
# sorry about that... -> sorry about that stick mine well mugsy think and person huh breathe base
# Epoch 67/100
# 7905/7905 [==============================] - 16s 2ms/step - loss: 1.3239
#
# Generating text after epoch: 66
# you mustve had your hands full... -> you mustve had your hands full point back this yeah rewired rach yeah academics underwear god
# oh wait i... -> oh wait i do list second yes girlfriend like for yeah okay okay
# oh wait i... -> oh wait i really gift much her wouldnt you first two really me
# sorry about that... -> sorry about that lord no boom really nurses your pants works you really
# Epoch 68/100
# 7905/7905 [==============================] - 16s 2ms/step - loss: 1.2726
#
# Generating text after epoch: 67
# you mustve had your hands full... -> you mustve had your hands full well cmere today so because seei like yes time needs
# oh wait i... -> oh wait i do do jew restaurant ouch i cars i comes yes
# oh wait i... -> oh wait i guy careful said me and scared feeling people friend phonetically
# sorry about that... -> sorry about that you doing impossible god again gift having watch is choice
# Epoch 69/100
# 7905/7905 [==============================] - 16s 2ms/step - loss: 1.3328
#
# Generating text after epoch: 68
# you mustve had your hands full... -> you mustve had your hands full hey movie jockstrap up means him go commercial yknow beautiful
# oh wait i... -> oh wait i blast off okay appalachia two you are about bonnie joey
# oh wait i... -> oh wait i go damnit no ohhh work off really expression she water
# sorry about that... -> sorry about that nothin my phoebe her no cards right top on yeah
# Epoch 70/100
# 7905/7905 [==============================] - 16s 2ms/step - loss: 1.2745
#
# Generating text after epoch: 69
# you mustve had your hands full... -> you mustve had your hands full dismissed to do oh right why great shot ya what
# oh wait i... -> oh wait i she down game please i has bathroom word party peeking
# oh wait i... -> oh wait i asteroid her me underwear lemonade man joey green as emily
# sorry about that... -> sorry about that this here chandler ear suzie yeah god house thinks me
# Epoch 71/100
# 7905/7905 [==============================] - 16s 2ms/step - loss: 1.2626
#
# Generating text after epoch: 70
# you mustve had your hands full... -> you mustve had your hands full matter me ahh really me hi could night whatever down
# oh wait i... -> oh wait i name friends here waitressing oh what out in chandler this
# oh wait i... -> oh wait i dont got you yes thing sweater not you handsome detail
# sorry about that... -> sorry about that no past bet what go on okay rach she but
# Epoch 72/100
# 7905/7905 [==============================] - 16s 2ms/step - loss: 1.4509
#
# Generating text after epoch: 71
# you mustve had your hands full... -> you mustve had your hands full night gellergreen it the incredibly interesting gift easy thirsty attic
# oh wait i... -> oh wait i ezels okay rules mean lemonade put hormones christmas ring no
# oh wait i... -> oh wait i it make wrong fashion poker mississpete wedding no we been
# sorry about that... -> sorry about that ive men babies looks honor casey grab expense else yeah
# Epoch 73/100
# 7905/7905 [==============================] - 16s 2ms/step - loss: 1.2614
#
# Generating text after epoch: 72
# you mustve had your hands full... -> you mustve had your hands full hey muse money partner and yeah here rewired principle joey
# oh wait i... -> oh wait i half who no go you and do am you thats
# oh wait i... -> oh wait i no yes so crazy me monica was it tag up
# sorry about that... -> sorry about that one talking oh we way do phoebe life punch long
# Epoch 74/100
# 7905/7905 [==============================] - 16s 2ms/step - loss: 1.2243
#
# Generating text after epoch: 73
# you mustve had your hands full... -> you mustve had your hands full one baby party know about yknow go wanna duude that
# oh wait i... -> oh wait i phone you you right be loaner sorry bummer start happen
# oh wait i... -> oh wait i you is bucks we hair true who uhh gonna no
# sorry about that... -> sorry about that no russia roommate wow place that claims before to reading
# Epoch 75/100
# 7905/7905 [==============================] - 16s 2ms/step - loss: 1.2427
#
# Generating text after epoch: 74
# you mustve had your hands full... -> you mustve had your hands full i paths out really stop okay dad her something myself
# oh wait i... -> oh wait i there happening wait right oh baby yeah whistle quarter and
# oh wait i... -> oh wait i really yeah get 700 youre snack on place yourself do
# sorry about that... -> sorry about that your pants place down married coffee name oh out no
# Epoch 76/100
# 7905/7905 [==============================] - 16s 2ms/step - loss: 1.1951
#
# Generating text after epoch: 75
# you mustve had your hands full... -> you mustve had your hands full true gift in special to entertainment focus know building be
# oh wait i... -> oh wait i yeah bug yet thursday stand daughter go what about boring
# oh wait i... -> oh wait i sisters yeah night noise them him birth casting junk really
# sorry about that... -> sorry about that water now wow for okay oh trib uh hey why
# Epoch 77/100
# 7905/7905 [==============================] - 16s 2ms/step - loss: 1.1682
#
# Generating text after epoch: 76
# you mustve had your hands full... -> you mustve had your hands full this a us might place you you paths oh her
# oh wait i... -> oh wait i on game me monica minute you any much like on
# oh wait i... -> oh wait i one barcelona me marcel what later and gone way a
# sorry about that... -> sorry about that here her breaths poem later him you love tie sucks
# Epoch 78/100
# 7905/7905 [==============================] - 16s 2ms/step - loss: 1.1421
#
# Generating text after epoch: 77
# you mustve had your hands full... -> you mustve had your hands full okay was say what all possible oh needs will didnt
# oh wait i... -> oh wait i idiot way plan hi just okay yeah dont of rach
# oh wait i... -> oh wait i now baths over and that something amazing us okay some
# sorry about that... -> sorry about that heyhey later why pregnant right just inappropriate detail homemade bob
# Epoch 79/100
# 7905/7905 [==============================] - 16s 2ms/step - loss: 1.1226
#
# Generating text after epoch: 78
# you mustve had your hands full... -> you mustve had your hands full not really okay nooo this me electricity this on in
# oh wait i... -> oh wait i now hey him gina i it yeah yeah doooo favour
# oh wait i... -> oh wait i universe roger roger tanned did kristen else you us want
# sorry about that... -> sorry about that anywhere there married possible goggles broken what yeah little yuhhuh
# Epoch 80/100
# 7905/7905 [==============================] - 16s 2ms/step - loss: 1.1152
#
# Generating text after epoch: 79
# you mustve had your hands full... -> you mustve had your hands full do no pass okay on cant is chelsea yknow is
# oh wait i... -> oh wait i me monica her the we king children theyre two god
# oh wait i... -> oh wait i dont i cant to coffee you okay ear her birth
# sorry about that... -> sorry about that lasagne job me well embarrassed huge so have no okay
# Epoch 81/100
# 7905/7905 [==============================] - 16s 2ms/step - loss: 1.0959
#
# Generating text after epoch: 80
# you mustve had your hands full... -> you mustve had your hands full oboe and wouldnt took what say baths five takeoff spatters
# oh wait i... -> oh wait i board pants kinda me phoebe yeah rach yourself gonna stumble
# oh wait i... -> oh wait i be kidney did something lasagne okay it slips daughter pheebs
# sorry about that... -> sorry about that god she out pig okay roger him gina okay basis
# Epoch 82/100
# 7905/7905 [==============================] - 16s 2ms/step - loss: 1.1141
#
# Generating text after epoch: 81
# you mustve had your hands full... -> you mustve had your hands full god this bandaid talk yours out really likes yeah me
# oh wait i... -> oh wait i second are sorry baby underwear yeah asked here here huh
# oh wait i... -> oh wait i birthday right does hand station yeah at what what out
# sorry about that... -> sorry about that coffee myself gang one yet no questions what time poppers
# Epoch 83/100
# 7905/7905 [==============================] - 16s 2ms/step - loss: 1.1068
#
# Generating text after epoch: 82
# you mustve had your hands full... -> you mustve had your hands full definitely uhh are her kid this roommate gift monica whoa
# oh wait i... -> oh wait i right really yeah group the amazing youyou cares boobies eh
# oh wait i... -> oh wait i it you gift mad right oh gift fun there sure
# sorry about that... -> sorry about that dont oh guess romantic phone thanks ring ended there night
# Epoch 84/100
# 7905/7905 [==============================] - 16s 2ms/step - loss: 1.1184
#
# Generating text after epoch: 83
# you mustve had your hands full... -> you mustve had your hands full am two boy joey see joey sure really and left
# oh wait i... -> oh wait i left this comet the id yeah off unbelievable baby underwear
# oh wait i... -> oh wait i care have see later okay nothing interesting be time doing
# sorry about that... -> sorry about that whos hole 6 chimney over you of coming you caller
# Epoch 85/100
# 7905/7905 [==============================] - 16s 2ms/step - loss: 1.2521
#
# Generating text after epoch: 84
# you mustve had your hands full... -> you mustve had your hands full hey daughter squash say hard now minute be mess ehh
# oh wait i... -> oh wait i ever know 15 sweater em congratulationsohwow im baby underwear on
# oh wait i... -> oh wait i please it okay jew then radiator me ring toast about
# sorry about that... -> sorry about that about donuts i face yeah night later strength mean of
# Epoch 86/100
# 7905/7905 [==============================] - 16s 2ms/step - loss: 1.1214
#
# Generating text after epoch: 85
# you mustve had your hands full... -> you mustve had your hands full oh there right to crazy yes please long wedding bye
# oh wait i... -> oh wait i seven market hang down sides what on anyway story friends
# oh wait i... -> oh wait i today her lotion goodacre are baby about me really gay
# sorry about that... -> sorry about that what um happened any okay stuff yes once okay off
# Epoch 87/100
# 7905/7905 [==============================] - 16s 2ms/step - loss: 1.0682
#
# Generating text after epoch: 86
# you mustve had your hands full... -> you mustve had your hands full chelsea what gift suzie asleep partner how come on me
# oh wait i... -> oh wait i song know anyone detail see passed you park burt you
# oh wait i... -> oh wait i preapproved you dont drag not phoebe dont i time confidant
# sorry about that... -> sorry about that right nice about like you annabelle ed lives but course
# Epoch 88/100
# 7905/7905 [==============================] - 16s 2ms/step - loss: 1.0497
#
# Generating text after epoch: 87
# you mustve had your hands full... -> you mustve had your hands full you question bathroom yeah weve here here there mine okay
# oh wait i... -> oh wait i hard later shes restaurant phoebe bathroom you paolo international all
# oh wait i... -> oh wait i god hi long guy wow well minute it drapes woman
# sorry about that... -> sorry about that i 2000 oh relax its i suityman at paints hit
# Epoch 89/100
# 7905/7905 [==============================] - 16s 2ms/step - loss: 1.0156
#
# Generating text after epoch: 88
# you mustve had your hands full... -> you mustve had your hands full pig doin group know one mess thanks hello hi here
# oh wait i... -> oh wait i much promise oh group good sea what to what know
# oh wait i... -> oh wait i happen weekend understand no job underwear you you money bigger
# sorry about that... -> sorry about that and i that mine building who wondering mess ring hero
# Epoch 90/100
# 7905/7905 [==============================] - 16s 2ms/step - loss: 0.9995
#
# Generating text after epoch: 89
# you mustve had your hands full... -> you mustve had your hands full this moving wedding god god scott thats line uhhuh quarter
# oh wait i... -> oh wait i suck huh this room damnit no womba over run phoebe
# oh wait i... -> oh wait i what phoebe controversial player out you annabelle her why no
# sorry about that... -> sorry about that guys joey doing park yeah sure well doing one stuff
# Epoch 91/100
# 7905/7905 [==============================] - 16s 2ms/step - loss: 0.9925
#
# Generating text after epoch: 90
# you mustve had your hands full... -> you mustve had your hands full maybe towel i do job me you course later you
# oh wait i... -> oh wait i no so true am two know up it joey this
# oh wait i... -> oh wait i strapping tiles you yeah what i far on nelson are
# sorry about that... -> sorry about that exactly are em wrong yum penis trib may money to
# Epoch 92/100
# 7905/7905 [==============================] - 16s 2ms/step - loss: 0.9777
#
# Generating text after epoch: 91
# you mustve had your hands full... -> you mustve had your hands full me monica god this go hey owow and yeah give
# oh wait i... -> oh wait i what name her scrud and no pig okay them cute
# oh wait i... -> oh wait i anything girl sense sure calm make oh your pants black
# sorry about that... -> sorry about that him gina and pants chair sandwich phoebe is yeah later
# Epoch 93/100
# 7905/7905 [==============================] - 16s 2ms/step - loss: 0.9672
#
# Generating text after epoch: 92
# you mustve had your hands full... -> you mustve had your hands full true out monana morning right hi green see did thanks
# oh wait i... -> oh wait i mom sorry lot yet can you comes here home i
# oh wait i... -> oh wait i okay green you coffee list yet suzie museum okay you
# sorry about that... -> sorry about that okay somethin out what said ticket i trying come well
# Epoch 94/100
# 7905/7905 [==============================] - 16s 2ms/step - loss: 0.9511
#
# Generating text after epoch: 93
# you mustve had your hands full... -> you mustve had your hands full her me you ole closing bag yeah list something name
# oh wait i... -> oh wait i winross is dont umhmm no kill what do sensitive me
# oh wait i... -> oh wait i here cant bus varrrrrrrrrrom joey than sweet right not much
# sorry about that... -> sorry about that yes say starlight question there hey it course i kinda
# Epoch 95/100
# 7905/7905 [==============================] - 16s 2ms/step - loss: 0.9471
#
# Generating text after epoch: 94
# you mustve had your hands full... -> you mustve had your hands full oh do chandler picturewow have get up job eh different
# oh wait i... -> oh wait i again face know you to know problem night mouth together
# oh wait i... -> oh wait i down comes gonna no charming turn this what no too
# sorry about that... -> sorry about that daughter purse god so god rachel here this what doing
# Epoch 96/100
# 7905/7905 [==============================] - 16s 2ms/step - loss: 0.9349
#
# Generating text after epoch: 95
# you mustve had your hands full... -> you mustve had your hands full what on scared mean layman talking sexy water okay somethin
# oh wait i... -> oh wait i no needs why man jockstrap me was me you you
# oh wait i... -> oh wait i annulment go married joe go remembered wedding to well paths
# sorry about that... -> sorry about that me upstairs you sweet up you done too pushing i
# Epoch 97/100
# 7905/7905 [==============================] - 16s 2ms/step - loss: 0.9218
#
# Generating text after epoch: 96
# you mustve had your hands full... -> you mustve had your hands full knock cooking this doing funny here was town i hey
# oh wait i... -> oh wait i here sandwiches heads happened here me was yeah concussion some
# oh wait i... -> oh wait i shoe ii it me um molly to what it no
# sorry about that... -> sorry about that like so now it there y come group right two
# Epoch 98/100
# 7905/7905 [==============================] - 16s 2ms/step - loss: 0.9072
#
# Generating text after epoch: 97
# you mustve had your hands full... -> you mustve had your hands full no seesaw hello i monica jew go window year when
# oh wait i... -> oh wait i free guys mad yeah still yes i loaner em you
# oh wait i... -> oh wait i who damn first no number a yeah huh chandler go
# sorry about that... -> sorry about that guess im underwear commercial month its goodbye what huh mail
# Epoch 99/100
# 7905/7905 [==============================] - 16s 2ms/step - loss: 0.9077
#
# Generating text after epoch: 98
# you mustve had your hands full... -> you mustve had your hands full son his no sorry deadend hey years down trib on
# oh wait i... -> oh wait i to too it chi imagine abandoner nervous down which bicep
# oh wait i... -> oh wait i nothin you ever um side huh this morning this you
# sorry about that... -> sorry about that you man joey it this scrud i yet yeah winross
# Epoch 100/100
# 7905/7905 [==============================] - 16s 2ms/step - loss: 0.9018
#
# Generating text after epoch: 99
# you mustve had your hands full... -> you mustve had your hands full rach you steel go hey again change goodnight you ready
# oh wait i... -> oh wait i her casey gellers im on up questions really funny waitwaitwaitwaitwaitwaitwaitwait
# oh wait i... -> oh wait i computer forgiving working huntley dont and bank party uhhmm em
# sorry about that... -> sorry about that alone nurses water yeah 46 me wouldnt anything stupid this

# %%
filtered_utterances.sample(5)
# Out:
#                                               Utterance  \
# 8180                       oh wait, i think i hear him.
# 5525  oh yeah, it must be tough to keep your hands o...
# 5692                 yeah, tell that to my uncle lenny.
# 5738    sorry about that. so. what have you been up to?
# 5481  first of all um, i love you both so much and y...
#
#                                     Reply  Season  Episode  Dialogue_ID  \
# 8180                      oh - oh my god!       9       12          953
# 5525    yeah, but im pretty sure hes gay.       8       12          649
# 5692           why? what happened to him?       3       15          664
# 5738         oh, not much. i-i got a job.       1        2          669
# 5481  okay, bla-bla-bla-bla!! who is it?!       7        6          646
#
#                     Generated_Reply           bleu  Utterance_ID  \
# 8180  oh my god! chad, is that you?   6.608447e-78  dia953_utt13
# 5525                   just hang in  1.254338e-154  dia649_utt21
# 5692   so how did it go? ah, we did   5.410823e-01   dia664_utt6
# 5738               oh my god, ross,   1.027019e-77   dia669_utt0
# 5481                            NaN   0.000000e+00   dia646_utt4
#
#                                                  tokens
# 8180            oh wait i think i hear him oh oh my god
# 5525  oh yeah it must be tough to keep your hands of...
# 5692  yeah tell that to my uncle lenny why what happ...
# 5738  sorry about that so what have you been up to o...
# 5481  first of all um i love you both so much and yo...

# %%
model.save_weights('lstm_weights.h5')

# %%
model.save('lstm.h5')

# %%
sample(model.predict(test_x[0])[-1], 0).shape
# Out:
# ()

# %%
np.argmax(model.predict(test_x[0]))
# Out:
# 273934

# %%
sample(model.predict(test_x[0])[-1], temperature=0.7)
# Out:
# 80081
